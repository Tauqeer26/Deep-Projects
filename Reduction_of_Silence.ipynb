# %% [raw]
# # In this notebook,silence from the audio file has been eliminated from the audio file and it is converted into 10 seconds with only cough sample with positive and negative, as labelled properly

# %%
import librosa,librosa.display 
import numpy as np
import librosa as lr
from glob import glob
import matplotlib.pyplot as plt
file ="F:/Covid-19 Project/cough-file/cough-file"
audio_files= glob(file + '/*.wav')
#len(audio_files)
for data in range(0,len(audio_files)):
    audio,sfreq=lr.load(audio_files[data],sr=22050)
    time=np.arange(0,len(audio)) / sfreq
    fig,ax=plt.subplots()
    ax.plot(time,audio)
    ax.set(xlabel='Time(s)',ylabel='amplitude')
    plt.show()

# %%
import librosa,librosa.display 
import numpy as np
import matplotlib.pyplot as plt
file ="F:/Covid-19 Project/cough-file/cough-file/neg-1.wav.wav"
signal,sr=librosa.load(file,sr=22050)
librosa.display.waveplot(signal,sr=sr)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
from pydub import AudioSegment
from pydub import AudioSegment
from pydub.playback import play
song = AudioSegment.from_wav("F:/Covid-19 Project/cough-file/cough-file/neg-1.wav.wav")


last_10_seconds = song[-10000:]#

end = last_10_seconds 
print(end)
com= end 

com.export("F:/Covid-19 Project/cough_converted/neg-1.wav", format="wav")
#play(com)
# Out:
# ...
# <_io.BufferedRandom name='F:/Covid-19 Project/cough_converted/neg-1.wav'>

# %%
#neg-1.wav.wav converted into neg-1.wav

# %%
import librosa,librosa.display 
import numpy as np
import matplotlib.pyplot as plt
file ="F:/Covid-19 Project/cough_converted/neg-1.wav"
signal,sr=librosa.load(file,sr=22050)
librosa.display.waveplot(signal,sr=sr)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
from pydub import AudioSegment
from pydub import AudioSegment
from pydub.playback import play
song = AudioSegment.from_wav("F:/Covid-19 Project/cough-file/cough-file/neg-2.wav.wav")

last_10_seconds = song[-10000:]

end = last_10_seconds
print(end)
com= end 

com.export("F:/Covid-19 Project/cough_converted/neg-2.wav", format="wav")
#play(com)
# Out:
# ...
# <_io.BufferedRandom name='F:/Covid-19 Project/cough_converted/neg-2.wav'>

# %%
#neg-2.wav.wav converted into neg-2.wav

# %%
import librosa,librosa.display 
import numpy as np
import matplotlib.pyplot as plt
file ="F:/Covid-19 Project/cough_converted/neg-2.wav"
signal,sr=librosa.load(file,sr=22050)
librosa.display.waveplot(signal,sr=sr)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
from pydub import AudioSegment
from pydub import AudioSegment
from pydub.playback import play
song = AudioSegment.from_wav("F:/Covid-19 Project/cough-file/cough-file/neg-3.wav.wav")


last_10_seconds = song[10000:20000]

end = last_10_seconds
print(end)
com= end 

com.export("F:/Covid-19 Project/cough_converted/neg-3.wav", format="wav")
#play(com)
# Out:
# ...
# <_io.BufferedRandom name='F:/Covid-19 Project/cough_converted/neg-3.wav'>

# %%
#neg-3.wav.wav converted into neg-3.wav

# %%
import librosa,librosa.display 
import numpy as np
import matplotlib.pyplot as plt
file ="F:/Covid-19 Project/cough_converted/neg-3.wav"
signal,sr=librosa.load(file,sr=22050)
librosa.display.waveplot(signal,sr=sr)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
from pydub import AudioSegment
from pydub import AudioSegment
from pydub.playback import play
song = AudioSegment.from_wav("F:/Covid-19 Project/cough-file/cough-file/pos-2.wav.wav")

last_10_seconds = song[23000:]

end = last_10_seconds
print(end)
com= end 

com.export("F:/Covid-19 Project/cough_converted/pos-2.wav", format="wav")
#play(com)
# Out:
# ...
# <_io.BufferedRandom name='F:/Covid-19 Project/cough_converted/pos-2.wav'>

# %%
#pos-2.wav.wav converted into pos-2.wav

# %%
import librosa,librosa.display 
import numpy as np
import matplotlib.pyplot as plt
file ="F:/Covid-19 Project/cough-file/cough-file/pos-2.wav.wav"
signal,sr=librosa.load(file,sr=22050)
librosa.display.waveplot(signal,sr=sr)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
from pydub import AudioSegment
from pydub import AudioSegment
from pydub.playback import play
song = AudioSegment.from_wav("F:/Covid-19 Project/cough-file/cough-file/pos-3.wav.wav")

last_10_seconds = song[21000:]
 
end = last_10_seconds
print(end)
com= end 

com.export("F:/Covid-19 Project/cough_converted/pos-3.wav", format="wav")
#play(com)
# Out:
# ...
# <_io.BufferedRandom name='F:/Covid-19 Project/cough_converted/pos-3.wav'>

# %%
#pos-3.wav.wav converted into pos-3.wav

# %%
import librosa,librosa.display 
import numpy as np
import matplotlib.pyplot as plt
file ="F:/Covid-19 Project/cough_converted/pos-3.wav"
signal,sr=librosa.load(file,sr=22050)
librosa.display.waveplot(signal,sr=sr)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()
